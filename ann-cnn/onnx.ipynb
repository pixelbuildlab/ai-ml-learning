# %%
import joblib
import numpy as np


ann_model = joblib.load("./server/assists/mnist_ann.model.joblib")
cnn_model = joblib.load("./server/assists/mnst_cnn.model.joblib")

ann_model.save('outs/ann.onnx', format="onnx")

# %%
import tensorflow as tf
import keras
import tf2onnx

print("TensorFlow:", tf.__version__)
print("Keras:", keras.__version__)
print("tf2onnx:", tf2onnx.__version__)
